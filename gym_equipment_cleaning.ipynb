# %%
import pandas as pd
import numpy as np
import re
import datetime

# %%
df_gym = pd.read_excel("Amazon.co.uk _ gym equipment_raw.xlsx")

# %%
df_gym.head()
# Out:
#                                              Product       Overall Stars  \
# 0  Yanlin Adjustable Multi-Function Barbell Rack ...  3.8 out of 5 stars
# 1  Yanlin Adjustable Multi-Function Barbell Rack ...  3.8 out of 5 stars
# 2  Yanlin Adjustable Multi-Function Barbell Rack ...  3.8 out of 5 stars
# 3  Yanlin Adjustable Multi-Function Barbell Rack ...  3.8 out of 5 stars
# 4  Yanlin Adjustable Multi-Function Barbell Rack ...  3.8 out of 5 stars
#
#   Number of Reviews       Price Title of Review Name   Individual Review  \
# 0        25 ratings  £89\n.\n98             NaN  NaN                 NaN
# 1        25 ratings  £89\n.\n98             NaN  NaN  4.0 out of 5 stars
# 2        25 ratings  £89\n.\n98             NaN  NaN  5.0 out of 5 stars
# 3        25 ratings  £89\n.\n98             NaN  NaN  2.0 out of 5 stars
# 4        25 ratings  £89\n.\n98             NaN  NaN  4.0 out of 5 stars
#
#                          Location and Date              Product Description  \
# 0                                      NaN                              NaN
# 1     Reviewed in Mexico on 29 August 2021  Colour Name: Advanced-B Version
# 2  Reviewed in Germany on 19 December 2021   Colour Name: Classic-A Version
# 3   Reviewed in Germany on 5 February 2022   Colour Name: Classic-A Version
# 4      Reviewed in Italy on 4 January 2022  Colour Name: Advanced-B Version
#
#                State                                             Review
# 0                NaN                                                NaN
# 1  Verified Purchase  Cumple con las expectativas solamente que una ...
# 2  Verified Purchase  Es wirkt sehr massiv für meine sportlichen Akt...
# 3  Verified Purchase  Material sehr wackelig, wirkt nicht vertrauens...
# 4  Verified Purchase  Venditore molto disponibile, mancavano dei pez...

# %%
df_gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19636 entries, 0 to 19635
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product              19636 non-null  object
#  1   Overall Stars        19636 non-null  object
#  2   Number of Reviews    19636 non-null  object
#  3   Price                13488 non-null  object
#  4   Title of Review      8748 non-null   object
#  5   Name                 8751 non-null   object
#  6   Individual Review    19591 non-null  object
#  7   Location and Date    19591 non-null  object
#  8   Product Description  7410 non-null   object
#  9   State                19061 non-null  object
#  10  Review               19546 non-null  object
# dtypes: object(11)
# memory usage: 1.6+ MB

# %%
df_gym = df_gym.astype(str)

# %%
df_gym[['Overall Stars', "Individual Review"]] = df_gym[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))
df_gym['Number of Reviews'] = df_gym['Number of Reviews'].map(lambda x: x.rstrip(' ratings'))
df_gym['Location and Date'] = df_gym['Location and Date'].apply(lambda x: x.lstrip('Reviewed in '))
df_gym['Number of Reviews'] = df_gym['Number of Reviews'].apply(lambda x: x.replace(',',''))

# %%
df_gym["Name"].value_counts()
# Out:
# nan                10885
# Amazon Customer      876
# Kindle Customer       34
# Michael               19
# Paul                  19
#                    ...
# Vasile Popescu         1
# C. Dennington          1
# roy ivers              1
# torrieh118             1
# Mike Jennings          1
# Name: Name, Length: 6679, dtype: int64

# %%
df_gym.head()
# Out:
#                                              Product Overall Stars  \
# 0  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 1  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 2  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 3  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 4  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
#
#   Number of Reviews       Price Title of Review Name Individual Review  \
# 0                25  £89\n.\n98             nan  nan               nan
# 1                25  £89\n.\n98             nan  nan               4.0
# 2                25  £89\n.\n98             nan  nan               5.0
# 3                25  £89\n.\n98             nan  nan               2.0
# 4                25  £89\n.\n98             nan  nan               4.0
#
#              Location and Date              Product Description  \
# 0                           an                              nan
# 1     Mexico on 29 August 2021  Colour Name: Advanced-B Version
# 2  Germany on 19 December 2021   Colour Name: Classic-A Version
# 3   Germany on 5 February 2022   Colour Name: Classic-A Version
# 4      Italy on 4 January 2022  Colour Name: Advanced-B Version
#
#                State                                             Review
# 0                nan                                                nan
# 1  Verified Purchase  Cumple con las expectativas solamente que una ...
# 2  Verified Purchase  Es wirkt sehr massiv für meine sportlichen Akt...
# 3  Verified Purchase  Material sehr wackelig, wirkt nicht vertrauens...
# 4  Verified Purchase  Venditore molto disponibile, mancavano dei pez...

# %%
df_gym["Date"] = df_gym["Location and Date"]
df_gym["Date"] = df_gym["Date"].apply(lambda x: x.split(' on ')[-1].strip())

# %%
df_gym.head()
# Out:
#                                              Product Overall Stars  \
# 0  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 1  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 2  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 3  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 4  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
#
#   Number of Reviews       Price Title of Review Name Individual Review  \
# 0                25  £89\n.\n98             nan  nan               nan
# 1                25  £89\n.\n98             nan  nan               4.0
# 2                25  £89\n.\n98             nan  nan               5.0
# 3                25  £89\n.\n98             nan  nan               2.0
# 4                25  £89\n.\n98             nan  nan               4.0
#
#              Location and Date              Product Description  \
# 0                           an                              nan
# 1     Mexico on 29 August 2021  Colour Name: Advanced-B Version
# 2  Germany on 19 December 2021   Colour Name: Classic-A Version
# 3   Germany on 5 February 2022   Colour Name: Classic-A Version
# 4      Italy on 4 January 2022  Colour Name: Advanced-B Version
#
#                State                                             Review  \
# 0                nan                                                nan
# 1  Verified Purchase  Cumple con las expectativas solamente que una ...
# 2  Verified Purchase  Es wirkt sehr massiv für meine sportlichen Akt...
# 3  Verified Purchase  Material sehr wackelig, wirkt nicht vertrauens...
# 4  Verified Purchase  Venditore molto disponibile, mancavano dei pez...
#
#                Date
# 0                an
# 1    29 August 2021
# 2  19 December 2021
# 3   5 February 2022
# 4    4 January 2022

# %%
df_gym["Location and Date"] = df_gym["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())

# %%
df_gym.head()
# Out:
#                                              Product Overall Stars  \
# 0  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 1  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 2  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 3  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 4  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
#
#   Number of Reviews       Price Title of Review Name Individual Review  \
# 0                25  £89\n.\n98             nan  nan               nan
# 1                25  £89\n.\n98             nan  nan               4.0
# 2                25  £89\n.\n98             nan  nan               5.0
# 3                25  £89\n.\n98             nan  nan               2.0
# 4                25  £89\n.\n98             nan  nan               4.0
#
#   Location and Date              Product Description              State  \
# 0                an                              nan                nan
# 1            Mexico  Colour Name: Advanced-B Version  Verified Purchase
# 2           Germany   Colour Name: Classic-A Version  Verified Purchase
# 3           Germany   Colour Name: Classic-A Version  Verified Purchase
# 4             Italy  Colour Name: Advanced-B Version  Verified Purchase
#
#                                               Review              Date
# 0                                                nan                an
# 1  Cumple con las expectativas solamente que una ...    29 August 2021
# 2  Es wirkt sehr massiv für meine sportlichen Akt...  19 December 2021
# 3  Material sehr wackelig, wirkt nicht vertrauens...   5 February 2022
# 4  Venditore molto disponibile, mancavano dei pez...    4 January 2022

# %%
df_gym.rename(columns={"Location and Date": "Location"}, inplace = True)

# %%
df_gym['Price'] = df_gym['Price'].apply(lambda x: x.replace('\n.\n','.'))
df_gym['Price'] = df_gym['Price'].apply(lambda x: x.replace('£',''))

# %%
df_gym.head()
# Out:
#                                              Product Overall Stars  \
# 0  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 1  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 2  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 3  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 4  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
#
#   Number of Reviews  Price Title of Review Name Individual Review Location  \
# 0                25  89.98             nan  nan               nan       an
# 1                25  89.98             nan  nan               4.0   Mexico
# 2                25  89.98             nan  nan               5.0  Germany
# 3                25  89.98             nan  nan               2.0  Germany
# 4                25  89.98             nan  nan               4.0    Italy
#
#                Product Description              State  \
# 0                              nan                nan
# 1  Colour Name: Advanced-B Version  Verified Purchase
# 2   Colour Name: Classic-A Version  Verified Purchase
# 3   Colour Name: Classic-A Version  Verified Purchase
# 4  Colour Name: Advanced-B Version  Verified Purchase
#
#                                               Review              Date
# 0                                                nan                an
# 1  Cumple con las expectativas solamente que una ...    29 August 2021
# 2  Es wirkt sehr massiv für meine sportlichen Akt...  19 December 2021
# 3  Material sehr wackelig, wirkt nicht vertrauens...   5 February 2022
# 4  Venditore molto disponibile, mancavano dei pez...    4 January 2022

# %%
df_gym[["day","month", "year"]] = df_gym["Date"].apply(lambda x: pd.Series(x.split(' ')))
df_gym["Date"] = pd.to_datetime(df_gym['year'].astype(str)  + df_gym['month'] + df_gym["day"], format='%Y%B%d')
df_gym.drop(columns = ["day", "month", "year"], inplace= True)

# %%
df_gym["Location"].value_counts()
# Out:
# the United Kingdom    8751
# the United States     6571
# Canada                1332
# Germany               1033
# Italy                  836
# France                 489
# Spain                  359
# Japan                   81
# an                      45
# Mexico                  43
# Australia               41
# India                   37
# Sweden                  10
# the Netherlands          6
# Singapore                2
# Name: Location, dtype: int64

# %%
df_gym['Location'] = df_gym['Location'].apply(lambda x: x.replace('the ',''))

# %%
df_gym["Location"].value_counts()
# Out:
# United Kingdom    8751
# United States     6571
# Canada            1332
# Germany           1033
# Italy              836
# France             489
# Spain              359
# Japan               81
# an                  45
# Mexico              43
# Australia           41
# India               37
# Sweden              10
# Netherlands          6
# Singapore            2
# Name: Location, dtype: int64

# %%
df_gym.isna().value_counts()
# Out:
# Product  Overall Stars  Number of Reviews  Price  Title of Review  Name   Individual Review  Location  Product Description  State  Review  Date
# False    False          False              False  False            False  False              False     False                False  False   False    19591
#                                                                                                                                            True        45
# dtype: int64

# %%
df_gym.head()
# Out:
#                                              Product Overall Stars  \
# 0  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 1  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 2  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 3  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
# 4  Yanlin Adjustable Multi-Function Barbell Rack ...           3.8
#
#   Number of Reviews  Price Title of Review Name Individual Review Location  \
# 0                25  89.98             nan  nan               nan       an
# 1                25  89.98             nan  nan               4.0   Mexico
# 2                25  89.98             nan  nan               5.0  Germany
# 3                25  89.98             nan  nan               2.0  Germany
# 4                25  89.98             nan  nan               4.0    Italy
#
#                Product Description              State  \
# 0                              nan                nan
# 1  Colour Name: Advanced-B Version  Verified Purchase
# 2   Colour Name: Classic-A Version  Verified Purchase
# 3   Colour Name: Classic-A Version  Verified Purchase
# 4  Colour Name: Advanced-B Version  Verified Purchase
#
#                                               Review       Date
# 0                                                nan        NaT
# 1  Cumple con las expectativas solamente que una ... 2021-08-29
# 2  Es wirkt sehr massiv für meine sportlichen Akt... 2021-12-19
# 3  Material sehr wackelig, wirkt nicht vertrauens... 2022-02-05
# 4  Venditore molto disponibile, mancavano dei pez... 2022-01-04

# %%
df_gym[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str).dtypes
df_gym[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_gym[["Number of Reviews"]].astype(int)
# Out:
#        Number of Reviews
# 0                     25
# 1                     25
# 2                     25
# 3                     25
# 4                     25
# ...                  ...
# 19631               9906
# 19632               9906
# 19633               9906
# 19634               9906
# 19635               9906
#
# [19636 rows x 1 columns]

# %%
df_gym.to_csv('gym_equipment_cleaned.csv')

# %%
df_gym[df_gym["Location"] == "United Kingdom"].shape
# Out:
# (8751, 12)

# %%
df_uk_gym = df_gym[df_gym["Location"] == "United Kingdom"]
df_uk_gym.to_csv('gym_equipment_uk_all_dates.csv')

# %%
df_uk_gym.describe()
# Out:
# <ipython-input-104-23100d80d5f7>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_uk_gym.describe()
#                                                   Product Overall Stars  \
# count                                                8751          8751
# unique                                                 43            12
# top     H&S Ab Abdominal Exercise Roller With Extra Th...           4.4
# freq                                                 1411          4238
# first                                                 NaN           NaN
# last                                                  NaN           NaN
#
#        Number of Reviews Price Title of Review             Name  \
# count               8751  8751            8751             8751
# unique                44    29            5587             6678
# top                10819   nan      Five Stars  Amazon Customer
# freq                1411  1806             485              876
# first                NaN   NaN             NaN              NaN
# last                 NaN   NaN             NaN              NaN
#
#        Individual Review        Location Product Description  \
# count               8751            8751                8751
# unique                 5               1                  98
# top                  5.0  United Kingdom                 nan
# freq                6233            8751                5523
# first                NaN             NaN                 NaN
# last                 NaN             NaN                 NaN
#
#                     State                    Review                 Date
# count                8751                      8751                 8751
# unique                  2                      8040                 2195
# top     Verified Purchase  Video Player is loading.  2014-08-13 00:00:00
# freq                 8263                        40                   48
# first                 NaN                       NaN  2011-10-12 00:00:00
# last                  NaN                       NaN  2022-02-18 00:00:00

# %%
df_uk_gym[(df_uk_gym["Date"] > "2019-12-01") & (df_uk_gym['Date'] <= "2020-04-01")]
# Out:
#                                                  Product Overall Stars  \
# 14     ComFy Mat Foam Exercise Mats, Gym Flooring Mat...           4.4
# 19     ComFy Mat Foam Exercise Mats, Gym Flooring Mat...           4.4
# 43     ComFy Mat Foam Exercise Mats, Gym Flooring Mat...           4.4
# 50     ComFy Mat Foam Exercise Mats, Gym Flooring Mat...           4.4
# 52     ComFy Mat Foam Exercise Mats, Gym Flooring Mat...           4.4
# ...                                                  ...           ...
# 19195  PROIRON 20kg Cast Iron Adjustable Dumbbell Set...           4.6
# 19203  PROIRON 20kg Cast Iron Adjustable Dumbbell Set...           4.6
# 19216  PROIRON 20kg Cast Iron Adjustable Dumbbell Set...           4.6
# 19218  PROIRON 20kg Cast Iron Adjustable Dumbbell Set...           4.6
# 19221  PROIRON 20kg Cast Iron Adjustable Dumbbell Set...           4.6
#
#       Number of Reviews  Price  \
# 14                 5698  19.95
# 19                 5698  19.95
# 43                 5698  19.95
# 50                 5698  19.95
# 52                 5698  19.95
# ...                 ...    ...
# 19195              9906  74.08
# 19203              9906  74.08
# 19216              9906  74.08
# 19218              9906  74.08
# 19221              9906  74.08
#
#                                          Title of Review  \
# 14       Cheap quality - not robust - dent easily - warp
# 19           Take time piecing together for best fitting
# 43                              Good little floor cover.
# 50     Reasonable quality. Wouldn’t say it’s great bu...
# 52     Very easy to fit and very hard wearing. Great ...
# ...                                                  ...
# 19195                                        As expected
# 19203                                          Recommend
# 19216               A solid investment for home training
# 19218                                        Starter Kit
# 19221                            Quailty value for money
#
#                        Name Individual Review        Location  \
# 14                       JT               1.0  United Kingdom
# 19           alexander reid               5.0  United Kingdom
# 43         The Turnip Queen               4.0  United Kingdom
# 50                   Faz R.               3.0  United Kingdom
# 52                 M. Smith               5.0  United Kingdom
# ...                     ...               ...             ...
# 19195                   Mas               5.0  United Kingdom
# 19203  Christine Filadelfia               4.0  United Kingdom
# 19216                  dima               5.0  United Kingdom
# 19218        Jamie Campbell               5.0  United Kingdom
# 19221               Fran S.               5.0  United Kingdom
#
#                                      Product Description              State  \
# 14     Size Name: 40 TILES (160 Square Feet)Colour Na...  Verified Purchase
# 19     Size Name: 24 TILES (96 Square Feet)Colour Nam...  Verified Purchase
# 43     Size Name: 10 TILES (40 Square Feet)Colour Nam...  Verified Purchase
# 50     Size Name: 12 TILES (48 Square Feet)Colour Nam...  Verified Purchase
# 52     Size Name: 16 TILES (64 Square Feet)Colour Nam...  Verified Purchase
# ...                                                  ...                ...
# 19195                                                nan                nan
# 19203                                                nan                nan
# 19216                                                nan  Verified Purchase
# 19218                                                nan  Verified Purchase
# 19221                                                nan  Verified Purchase
#
#                                                   Review       Date
# 14     I purchased these for my garage floor (we don'... 2019-12-30
# 19     After reading some good and some not so good r... 2020-02-22
# 43     I am using these on the kitchen floor of our f... 2020-02-01
# 50     It’s an OK product but there are a number of d... 2020-02-01
# 52     So easy to fit together and very hard wearing.... 2020-01-06
# ...                                                  ...        ...
# 19195                                       Good quality 2020-02-05
# 19203                                Perfect i recommend 2020-02-01
# 19216  I was looking for some weight due to my gym cl... 2020-03-24
# 19218  This is a great starter kit for anyone wanting... 2020-03-30
# 19221  Beautifuly made great quaility and great value... 2020-02-27
#
# [523 rows x 12 columns]

# %%
df_uk_gym_covd_dates = df_uk_gym[(df_uk_gym["Date"] > "2019-12-01") & (df_uk_gym['Date'] <= "2020-04-01")]

# %%
df_uk_gym_covd_dates.shape
# Out:
# (523, 12)

# %%
df_uk_gym_covd_dates.to_csv("gym_equipment_uk_covid_dates.csv")

# %%
print(df_uk_gym_covd_dates.groupby("Product")["State"].describe())
# Out:
#                                                    count unique  \
# Product
# AOMEES Hand Grips Strengthener Exerciser Equipm...     8      1
# ComFy Mat Foam Exercise Mats, Gym Flooring Mat,...    62      1
# DAWOO Battle Rope, Strength Training Rope, Batt...     3      1
# DMoose Fitness Hanging Ab Straps for Abdominal ...    17      2
# Fat Gripz Pro - The Simple Proven Way to Get Bi...    55      1
# Foam Mats Interlocking Foam Floor Mats 20 Piece...    16      2
# H&S Ab Abdominal Exercise Roller With Extra Thi...   125      2
# JX FITNESS Power Tower Adjustable Dip Station P...     8      1
# KATIX Training Equipment Grippy Handle                 8      1
# PROIRON 20kg Cast Iron Adjustable Dumbbell Set ...   118      2
# Phoenix Fitness RY1051 Exercise Dice for Workou...     3      1
# Podazz Super Kegel Exerciser Pelgrip Pelvis Flo...     5      1
# SONGMICS Exercise Bike, Fitness Bicycle, Foldab...     5      1
# TRX All-in-One Suspension Trainer and Bundle Ki...     6      1
# TRX GO Suspension Trainer System: Lightweight a...    15      1
# The TRX PRO3 Suspension Trainer -  for Professi...     2      2
# WINNOW Adjustable Weight Bench Foldable Home Ex...    10      2
# WINNOW Adjustable Weight Bench with Dip Station...     9      1
# Wonder Core 2 with built in Twisting Seat and R...    15      1
# YOLEO Adjustable Power Tower - Multi Function P...     8      2
# YOLEO Adjustable Weight Bench - Utility Weight ...    25      1
#
#                                                                   top freq
# Product
# AOMEES Hand Grips Strengthener Exerciser Equipm...  Verified Purchase    8
# ComFy Mat Foam Exercise Mats, Gym Flooring Mat,...  Verified Purchase   62
# DAWOO Battle Rope, Strength Training Rope, Batt...  Verified Purchase    3
# DMoose Fitness Hanging Ab Straps for Abdominal ...  Verified Purchase   16
# Fat Gripz Pro - The Simple Proven Way to Get Bi...  Verified Purchase   55
# Foam Mats Interlocking Foam Floor Mats 20 Piece...  Verified Purchase   15
# H&S Ab Abdominal Exercise Roller With Extra Thi...  Verified Purchase  124
# JX FITNESS Power Tower Adjustable Dip Station P...  Verified Purchase    8
# KATIX Training Equipment Grippy Handle              Verified Purchase    8
# PROIRON 20kg Cast Iron Adjustable Dumbbell Set ...  Verified Purchase  114
# Phoenix Fitness RY1051 Exercise Dice for Workou...  Verified Purchase    3
# Podazz Super Kegel Exerciser Pelgrip Pelvis Flo...  Verified Purchase    5
# SONGMICS Exercise Bike, Fitness Bicycle, Foldab...  Verified Purchase    5
# TRX All-in-One Suspension Trainer and Bundle Ki...  Verified Purchase    6
# TRX GO Suspension Trainer System: Lightweight a...  Verified Purchase   15
# The TRX PRO3 Suspension Trainer -  for Professi...                nan    1
# WINNOW Adjustable Weight Bench Foldable Home Ex...                nan    6
# WINNOW Adjustable Weight Bench with Dip Station...  Verified Purchase    9
# Wonder Core 2 with built in Twisting Seat and R...  Verified Purchase   15
# YOLEO Adjustable Power Tower - Multi Function P...  Verified Purchase    7
# YOLEO Adjustable Weight Bench - Utility Weight ...  Verified Purchase   25
