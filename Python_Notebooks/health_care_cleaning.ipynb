# %%
import pandas as pd
import numpy as np
import re
import datetime

# %%
df_health_1 = pd.read_excel("../Raw(uncleaned) csv files/Amazon.co.uk _ health care_raw_1.xlsx")
df_health_2 = pd.read_excel("../Raw(uncleaned) csv files/Amazon.co.uk _ health care_raw_2.xlsx")
df_health_3 = pd.read_excel("../Raw(uncleaned) csv files/Amazon.co.uk _ health care_raw_3.xlsx")
df_health_4 = pd.read_excel("../Raw(uncleaned) csv files/Amazon.co.uk _ health care_raw_4.xlsx")
df_health_5 = pd.read_excel("../Raw(uncleaned) csv files/Amazon.co.uk _ health care_raw_5.xlsx")
df_health_6 = pd.read_excel("../Raw(uncleaned) csv files/Amazon.co.uk _ health care_raw_6.xlsx")

# %%
df_health_1.describe()
# Out:
#                                                   Product       Overall Stars  \
# count                                                 960                 959
# unique                                                  8                   4
# top     NRS Healthcare M15691 Portable Overbed/Chair T...  4.5 out of 5 stars
# freq                                                  872                 872
#
#        Number of Reviews       Price Title of Review             Name  \
# count                959           6             658              957
# unique                 7           4             436              855
# top        2,547 ratings  £15\n.\n99      Five Stars  Amazon Customer
# freq                 872           3             106               54
#
#          Individual Review                                Location and Date  \
# count                  957                                              957
# ...

# %%
df_health_1[['Overall Stars', "Individual Review"]] = df_health_1[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))
df_health_2[['Overall Stars', "Individual Review"]] = df_health_2[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))
df_health_3[['Overall Stars', "Individual Review"]] = df_health_3[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))
df_health_4[['Overall Stars', "Individual Review"]] = df_health_4[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))
df_health_5[['Overall Stars', "Individual Review"]] = df_health_5[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))
df_health_6[['Overall Stars', "Individual Review"]] = df_health_6[['Overall Stars', "Individual Review"]].apply(lambda x: x.str.rstrip(' out of 5 stars'))

# %%
df_health_1.head()
# Out:
#                                              Product Overall Stars  \
# 0  Garden of Life Raw Probiotics Vaginal Care (Sh...           4.6
# 1  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 2  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 3  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 4  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
#
#   Number of Reviews       Price                              Title of Review  \
# 0     3,859 ratings  £33\n.\n51                                        Poor.
# 1       375 ratings         NaN            Good selection of different sizes
# 2       375 ratings         NaN                               Very Practical
# 3       375 ratings         NaN                                     worth it
# 4       375 ratings         NaN  Great starter kit to find the correct size.
#
#               Name Individual Review  \
# 0        Meg Rowse               1.0
# ...

# %%
df_health_1['Location and Date'].describe()
# Out:
# count                                                 957
# unique                                                873
# top       Reviewed in the United Kingdom on 28 March 2021
# freq                                                    3
# Name: Location and Date, dtype: object

# %%
df_health_1['Location and Date'] = df_health_1['Location and Date'].astype(str)
df_health_2['Location and Date'] = df_health_2['Location and Date'].astype(str)
df_health_3['Location and Date'] = df_health_3['Location and Date'].astype(str)
df_health_4['Location and Date'] = df_health_4['Location and Date'].astype(str)
df_health_5['Location and Date'] = df_health_5['Location and Date'].astype(str)
df_health_6['Location and Date'] = df_health_6['Location and Date'].astype(str)

# %%
df_health_1['Location and Date'] = df_health_1['Location and Date'].apply(lambda x: x.lstrip('Reviewed in the '))
df_health_2['Location and Date'] = df_health_2['Location and Date'].apply(lambda x: x.lstrip('Reviewed in the '))
df_health_3['Location and Date'] = df_health_3['Location and Date'].apply(lambda x: x.lstrip('Reviewed in the '))
df_health_4['Location and Date'] = df_health_4['Location and Date'].apply(lambda x: x.lstrip('Reviewed in the '))
df_health_5['Location and Date'] = df_health_5['Location and Date'].apply(lambda x: x.lstrip('Reviewed in the '))
df_health_6['Location and Date'] = df_health_6['Location and Date'].apply(lambda x: x.lstrip('Reviewed in the '))

# %%
df_health_1['Number of Reviews'] = df_health_1['Number of Reviews'].astype(str)
df_health_2['Number of Reviews'] = df_health_2['Number of Reviews'].astype(str)
df_health_3['Number of Reviews'] = df_health_3['Number of Reviews'].astype(str)
df_health_4['Number of Reviews'] = df_health_4['Number of Reviews'].astype(str)
df_health_5['Number of Reviews'] = df_health_5['Number of Reviews'].astype(str)
df_health_6['Number of Reviews'] = df_health_6['Number of Reviews'].astype(str)

# %%
df_health_1['Number of Reviews'] = df_health_1['Number of Reviews'].apply(lambda x: x.replace(',',''))
df_health_2['Number of Reviews'] = df_health_2['Number of Reviews'].apply(lambda x: x.replace(',',''))
df_health_3['Number of Reviews'] = df_health_3['Number of Reviews'].apply(lambda x: x.replace(',',''))
df_health_4['Number of Reviews'] = df_health_4['Number of Reviews'].apply(lambda x: x.replace(',',''))
df_health_5['Number of Reviews'] = df_health_5['Number of Reviews'].apply(lambda x: x.replace(',',''))
df_health_6['Number of Reviews'] = df_health_6['Number of Reviews'].apply(lambda x: x.replace(',',''))

# %%
df_health_1['Number of Reviews'] = df_health_1['Number of Reviews'].apply(lambda x: x.rstrip(' ratings'))
df_health_2['Number of Reviews'] = df_health_2['Number of Reviews'].apply(lambda x: x.rstrip(' ratings'))
df_health_3['Number of Reviews'] = df_health_3['Number of Reviews'].apply(lambda x: x.rstrip(' ratings'))
df_health_4['Number of Reviews'] = df_health_4['Number of Reviews'].apply(lambda x: x.rstrip(' ratings'))
df_health_5['Number of Reviews'] = df_health_5['Number of Reviews'].apply(lambda x: x.rstrip(' ratings'))
df_health_6['Number of Reviews'] = df_health_6['Number of Reviews'].apply(lambda x: x.rstrip(' ratings'))

# %%
df_health_1['Helpful'] = df_health_1['Helpful'].astype(str)
df_health_2['Helpful'] = df_health_2['Helpful'].astype(str)
df_health_3['Helpful'] = df_health_3['Helpful'].astype(str)
df_health_4['Helpful'] = df_health_4['Helpful'].astype(str)
df_health_5['Helpful'] = df_health_5['Helpful'].astype(str)
df_health_6['Helpful'] = df_health_6['Helpful'].astype(str)

# %%
df_health_1['Helpful'] = df_health_1['Helpful'].apply(lambda x: x.replace(',',''))
df_health_2['Helpful'] = df_health_2['Helpful'].apply(lambda x: x.replace(',',''))
df_health_3['Helpful'] = df_health_3['Helpful'].apply(lambda x: x.replace(',',''))
df_health_4['Helpful'] = df_health_4['Helpful'].apply(lambda x: x.replace(',',''))
df_health_5['Helpful'] = df_health_5['Helpful'].apply(lambda x: x.replace(',',''))
df_health_6['Helpful'] = df_health_6['Helpful'].apply(lambda x: x.replace(',',''))

# %%
df_health_1.head()
# Out:
#                                              Product Overall Stars  \
# 0  Garden of Life Raw Probiotics Vaginal Care (Sh...           4.6
# 1  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 2  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 3  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 4  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
#
#   Number of Reviews       Price                              Title of Review  \
# 0              3859  £33\n.\n51                                        Poor.
# 1               375         NaN            Good selection of different sizes
# 2               375         NaN                               Very Practical
# 3               375         NaN                                     worth it
# 4               375         NaN  Great starter kit to find the correct size.
#
#               Name Individual Review                  Location and Date  \
# ...

# %%
df_health_1["Date"] = df_health_1["Location and Date"]
df_health_2["Date"] = df_health_2["Location and Date"]
df_health_3["Date"] = df_health_3["Location and Date"]
df_health_4["Date"] = df_health_4["Location and Date"]
df_health_5["Date"] = df_health_5["Location and Date"]
df_health_6["Date"] = df_health_6["Location and Date"]

# %%
df_health_1["Date"] = df_health_1["Date"].apply(lambda x: x.split(' on ')[-1].strip())
df_health_2["Date"] = df_health_2["Date"].apply(lambda x: x.split(' on ')[-1].strip())
df_health_3["Date"] = df_health_3["Date"].apply(lambda x: x.split(' on ')[-1].strip())
df_health_4["Date"] = df_health_4["Date"].apply(lambda x: x.split(' on ')[-1].strip())
df_health_5["Date"] = df_health_5["Date"].apply(lambda x: x.split(' on ')[-1].strip())
df_health_6["Date"] = df_health_6["Date"].apply(lambda x: x.split(' on ')[-1].strip())

# %%
df_health_1["Location and Date"] = df_health_1["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())
df_health_2["Location and Date"] = df_health_2["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())
df_health_3["Location and Date"] = df_health_3["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())
df_health_4["Location and Date"] = df_health_4["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())
df_health_5["Location and Date"] = df_health_5["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())
df_health_6["Location and Date"] = df_health_6["Location and Date"].apply(lambda x: x.split(' on ')[0].strip())

# %%
df_health_1.head()
# Out:
#                                              Product Overall Stars  \
# 0  Garden of Life Raw Probiotics Vaginal Care (Sh...           4.6
# 1  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 2  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 3  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 4  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
#
#   Number of Reviews       Price                              Title of Review  \
# 0              3859  £33\n.\n51                                        Poor.
# 1               375         NaN            Good selection of different sizes
# 2               375         NaN                               Very Practical
# 3               375         NaN                                     worth it
# 4               375         NaN  Great starter kit to find the correct size.
#
#               Name Individual Review Location and Date Product Description  \
# ...

# %%
df_health_1.rename(columns={"Location and Date": "Location"}, inplace = True)
df_health_2.rename(columns={"Location and Date": "Location"}, inplace = True)
df_health_3.rename(columns={"Location and Date": "Location"}, inplace = True)
df_health_4.rename(columns={"Location and Date": "Location"}, inplace = True)
df_health_5.rename(columns={"Location and Date": "Location"}, inplace = True)
df_health_6.rename(columns={"Location and Date": "Location"}, inplace = True)

# %%
df_health_1['Price'] = df_health_1['Price'].astype(str)
df_health_2['Price'] = df_health_2['Price'].astype(str)
df_health_3['Price'] = df_health_3['Price'].astype(str)
df_health_4['Price'] = df_health_4['Price'].astype(str)
df_health_5['Price'] = df_health_5['Price'].astype(str)
df_health_6['Price'] = df_health_6['Price'].astype(str)

# %%
df_health_1['Price'] = df_health_1['Price'].apply(lambda x: x.replace('\n.\n','.'))
df_health_2['Price'] = df_health_2['Price'].apply(lambda x: x.replace('\n.\n','.'))
df_health_3['Price'] = df_health_3['Price'].apply(lambda x: x.replace('\n.\n','.'))
df_health_4['Price'] = df_health_4['Price'].apply(lambda x: x.replace('\n.\n','.'))
df_health_5['Price'] = df_health_5['Price'].apply(lambda x: x.replace('\n.\n','.'))
df_health_6['Price'] = df_health_6['Price'].apply(lambda x: x.replace('\n.\n','.'))

# %%
df_health_1['Price'] = df_health_1['Price'].apply(lambda x: x.replace('£',''))
df_health_2['Price'] = df_health_2['Price'].apply(lambda x: x.replace('£',''))
df_health_3['Price'] = df_health_3['Price'].apply(lambda x: x.replace('£',''))
df_health_4['Price'] = df_health_4['Price'].apply(lambda x: x.replace('£',''))
df_health_5['Price'] = df_health_5['Price'].apply(lambda x: x.replace('£',''))
df_health_6['Price'] = df_health_6['Price'].apply(lambda x: x.replace('£',''))

# %%
df_health_1[["day","month", "year"]] = df_health_1["Date"].apply(lambda x: pd.Series(x.split(' ')))
df_health_2[["day","month", "year"]] = df_health_2["Date"].apply(lambda x: pd.Series(x.split(' ')))
df_health_3[["day","month", "year"]] = df_health_3["Date"].apply(lambda x: pd.Series(x.split(' ')))
df_health_4[["day","month", "year"]] = df_health_4["Date"].apply(lambda x: pd.Series(x.split(' ')))
df_health_5[["day","month", "year"]] = df_health_5["Date"].apply(lambda x: pd.Series(x.split(' ')))
df_health_6[["day","month", "year"]] = df_health_6["Date"].apply(lambda x: pd.Series(x.split(' ')))

# %%
df_health_1["Date"] = pd.to_datetime(df_health_1['year'].astype(str)  + df_health_1['month'] + df_health_1["day"], format='%Y%B%d')
df_health_2["Date"] = pd.to_datetime(df_health_2['year'].astype(str)  + df_health_2['month'] + df_health_2["day"], format='%Y%B%d')
df_health_3["Date"] = pd.to_datetime(df_health_3['year'].astype(str)  + df_health_3['month'] + df_health_3["day"], format='%Y%B%d')
df_health_4["Date"] = pd.to_datetime(df_health_4['year'].astype(str)  + df_health_4['month'] + df_health_4["day"], format='%Y%B%d')
df_health_5["Date"] = pd.to_datetime(df_health_5['year'].astype(str)  + df_health_5['month'] + df_health_5["day"], format='%Y%B%d')
df_health_6["Date"] = pd.to_datetime(df_health_6['year'].astype(str)  + df_health_6['month'] + df_health_6["day"], format='%Y%B%d')

# %%
df_health_4.head()
# Out:
#                                              Product Overall Stars  \
# 0  The 6-Minute Diary | Gratitude Journal for Men...           4.6
# 1  The 6-Minute Diary | Gratitude Journal for Men...           4.6
# 2  The 6-Minute Diary | Gratitude Journal for Men...           4.6
# 3  The 6-Minute Diary | Gratitude Journal for Men...           4.6
# 4  The 6-Minute Diary | Gratitude Journal for Men...           4.6
#
#   Number of Reviews Price Title of Review            Name Individual Review  \
# 0              5560   nan             NaN         FLDanae               3.0
# 1              5560   nan             NaN           A. G.               5.0
# 2              5560   nan             NaN          Nadine               5.0
# 3              5560   nan             NaN          Alicia               5.0
# 4              5560   nan             NaN  Cliente Amazon               4.0
#
#   Location                        Product Description              State  \
# ...

# %%
df_health_1.drop(columns = ["day", "month", "year"], inplace= True)
df_health_2.drop(columns = ["day", "month", "year"], inplace= True)
df_health_3.drop(columns = ["day", "month", "year"], inplace= True)
df_health_4.drop(columns = ["day", "month", "year"], inplace= True)
df_health_5.drop(columns = ["day", "month", "year"], inplace= True)
df_health_6.drop(columns = ["day", "month", "year"], inplace= True)

# %%
df_health_1["Helpful"] = df_health_1["Helpful"].apply(lambda x: x.rstrip('people found this helpful'))
df_health_2["Helpful"] = df_health_2["Helpful"].apply(lambda x: x.rstrip('people found this helpful'))
df_health_3["Helpful"] = df_health_3["Helpful"].apply(lambda x: x.rstrip('people found this helpful'))
df_health_4["Helpful"] = df_health_4["Helpful"].apply(lambda x: x.rstrip('people found this helpful'))
df_health_5["Helpful"] = df_health_5["Helpful"].apply(lambda x: x.rstrip('people found this helpful'))
df_health_6["Helpful"] = df_health_6["Helpful"].apply(lambda x: x.rstrip('people found this helpful'))

# %%
df_health_1["Helpful"].replace(['One per', "na"], [1, 0], inplace = True)
df_health_2["Helpful"].replace(['One per', "na"], [1, 0], inplace = True)
df_health_3["Helpful"].replace(['One per', "na"], [1, 0], inplace = True)
df_health_4["Helpful"].replace(['One per', "na"], [1, 0], inplace = True)
df_health_5["Helpful"].replace(['One per', "na"], [1, 0], inplace = True)
df_health_6["Helpful"].replace(['One per', "na"], [1, 0], inplace = True)

# %%
df_health_1["Number of Reviews"].replace('', 0, inplace=True)
df_health_2["Number of Reviews"].replace('', 0, inplace=True)
df_health_3["Number of Reviews"].replace('', 0, inplace=True)
df_health_4["Number of Reviews"].replace('', 0, inplace=True)
df_health_5["Number of Reviews"].replace('', 0, inplace=True)
df_health_6["Number of Reviews"].replace('', 0, inplace=True)

# %%
df_health_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product              960 non-null    object
#  1   Overall Stars        959 non-null    object
#  2   Number of Reviews    960 non-null    object
#  3   Price                960 non-null    object
#  4   Title of Review      658 non-null    object
#  5   Name                 957 non-null    object
#  6   Individual Review    957 non-null    object
#  7   Location             960 non-null    object
#  8   Product Description  6 non-null      object
#  9   State                947 non-null    object
#  10  Review               957 non-null    object
#  11  Helpful              960 non-null    object
#  12  Date                 957 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 97.6+ KB

# %%
df_health_1[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str).dtypes
df_health_1[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_health_1[["Number of Reviews", "Helpful"]].astype(int)
# Out:
#      Number of Reviews  Helpful
# 0                 3859        4
# 1                  375        0
# 2                  375        0
# 3                  375        0
# 4                  375        0
# ..                 ...      ...
# 955                 33        0
# 956                319        0
# 957                319        1
# 958                319        0
# 959                  0        0
#
# [960 rows x 2 columns]

# %%
df_health_2[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str).dtypes
df_health_2[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_health_2[["Number of Reviews", "Helpful"]].astype(int)
# Out:
#      Number of Reviews  Helpful
# 0                 2245        0
# 1                 2245        0
# 2                 2245        0
# 3                 2245        0
# 4                 2245        0
# ..                 ...      ...
# 197               1406       48
# 198               1406       18
# 199               1406        2
# 200               1406        3
# 201               1406        3
#
# [202 rows x 2 columns]

# %%
df_health_3[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str).dtypes
df_health_3[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_health_3[["Number of Reviews", "Helpful"]].astype(int)
# Out:
#        Number of Reviews  Helpful
# 0                   2441        0
# 1                   2441        0
# 2                   2441        0
# 3                   2441        0
# 4                   2441        0
# ...                  ...      ...
# 19995               2245        0
# 19996               2245        1
# 19997               2245        0
# 19998               2245        0
# 19999               2245        0
#
# [20000 rows x 2 columns]

# %%
df_health_4[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str).dtypes
df_health_4[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_health_4[["Number of Reviews", "Helpful"]].astype(int)
# Out:
#        Number of Reviews  Helpful
# 0                   5560        3
# 1                   5560        3
# 2                   5560        0
# 3                   5560        0
# 4                   5560        0
# ...                  ...      ...
# 19995               2441        0
# 19996               2441        0
# 19997               2441        2
# 19998               2441        0
# 19999               2441        0
#
# [20000 rows x 2 columns]

# %%
df_health_5[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str).dtypes
df_health_5[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_health_5[["Number of Reviews", "Helpful"]].astype(int)
# Out:
#        Number of Reviews  Helpful
# 0                   6690        3
# 1                   6690        0
# 2                   6690        1
# 3                   6690        0
# 4                   6690        0
# ...                  ...      ...
# 19995               5560        3
# 19996               5560        2
# 19997               5560        1
# 19998               5560        3
# 19999               5560        6
#
# [20000 rows x 2 columns]

# %%
df_health_6[["Product", "Title of Review", "Name", "Location", "State", "Review"]].astype(str)
df_health_6[["Overall Stars", "Price", "Individual Review"]].astype(float)
df_health_6[["Number of Reviews", "Helpful"]].astype(int)
# Out:
#        Number of Reviews  Helpful
# 0                    107        0
# 1                    107        1
# 2                    107        4
# 3                    107        0
# 4                    107        0
# ...                  ...      ...
# 19995               6690        1
# 19996               6690        0
# 19997               6690        0
# 19998               6690        0
# 19999               6690        5
#
# [20000 rows x 2 columns]

# %%
df_uk_health = pd.DataFrame()

# %%
df_uk_health = pd.concat([df_health_1, df_health_2, df_health_3, df_health_4, df_health_5, df_health_6], ignore_index = True)

# %%
df_uk_health
# Out:
#                                                  Product Overall Stars  \
# 0      Garden of Life Raw Probiotics Vaginal Care (Sh...           4.6
# 1      TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 2      TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 3      TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 4      TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# ...                                                  ...           ...
# 81157  The 6-Minute Diary Pure | Gratitude Journal, M...           4.6
# 81158  The 6-Minute Diary Pure | Gratitude Journal, M...           4.6
# 81159  The 6-Minute Diary Pure | Gratitude Journal, M...           4.6
# 81160  The 6-Minute Diary Pure | Gratitude Journal, M...           4.6
# 81161  The 6-Minute Diary Pure | Gratitude Journal, M...           4.6
#
#       Number of Reviews  Price                              Title of Review  \
# ...

# %%
df_uk_health["Location"].value_counts()
# Out:
# United Kingdom    58618
# Germany           10087
# United States      7129
# Italy              1486
# France             1126
# Spain              1105
# Canada              619
# Japan               605
# an                  188
# Australia           113
# Mexico               59
# Netherlands          15
# Sweden                7
# India                 5
# Name: Location, dtype: int64

# %%
df_uk_health = df_uk_health[df_uk_health["Location"].isin(["United Kingdom", "United States", "Canada", "India", "Australia"])]

# %%
df_covid_dates = df_uk_health[(df_uk_health["Date"] > "2019-12-01") & (df_uk_health['Date'] <= "2020-08-01")]

# %%
df_covid_dates.shape
# Out:
# (9970, 13)

# %%
df_covid_dates["Location"].value_counts()
# Out:
# United Kingdom    7803
# United States     2077
# Canada              54
# Australia           31
# India                5
# Name: Location, dtype: int64

# %%
df_covid_dates.head()
# Out:
#                                               Product Overall Stars  \
# 2   TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 3   TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 20  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 46  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
# 49  TePe Oral Health Care, Interdental Brush, Mixe...           4.6
#
#    Number of Reviews Price Title of Review             Name Individual Review  \
# 2                375   nan  Very Practical       Betty Boop               5.0
# 3                375   nan        worth it  julie middleton               5.0
# 20               375   nan           Happy            Linda               5.0
# 46               375   nan    Good mixture  Amazon Customer               4.0
# 49               375   nan            Good  Amazon Customer               4.0
#
#           Location Product Description              State  \
# ...

# %%
df_covid_dates = df_covid_dates.drop(columns=["Overall Stars", "Number of Reviews", "Title of Review", "Product Description", "State", "Name"])

# %%
df_covid_dates.head()
# Out:
#                                               Product Price Individual Review  \
# 2   TePe Oral Health Care, Interdental Brush, Mixe...   nan               5.0
# 3   TePe Oral Health Care, Interdental Brush, Mixe...   nan               5.0
# 20  TePe Oral Health Care, Interdental Brush, Mixe...   nan               5.0
# 46  TePe Oral Health Care, Interdental Brush, Mixe...   nan               4.0
# 49  TePe Oral Health Care, Interdental Brush, Mixe...   nan               4.0
#
#           Location                                             Review Helpful  \
# 2   United Kingdom  I used to order the different coloured brushes...       0
# 3   United Kingdom  Fine it you have different size gaps between y...       0
# 20  United Kingdom                                         Very happy       0
# 46  United Kingdom  Work quite well but after a couple of use they...       0
# 49  United Kingdom                                               Good       0
#
#          Date
# ...

# %%
df_covid_dates.insert(1, 'Category', 'Health Care')

# %%
df_covid_dates.dtypes
# Out:
# Product                      object
# Category                     object
# Price                        object
# Individual Review            object
# Location                     object
# Review                       object
# Helpful                      object
# Date                 datetime64[ns]
# dtype: object

# %%
df_covid_dates = df_covid_dates[["Product", "Category", "Price", "Individual Review", "Location", "Date", "Review", "Helpful"]]
df_covid_dates
# Out:
#                                                  Product     Category Price  \
# 2      TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 3      TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 20     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 46     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 49     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# ...                                                  ...          ...   ...
# 80897  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 80912  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 80914  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 80919  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 80922  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
#
#       Individual Review        Location       Date  \
# ...

# %%
df_covid_dates.reset_index(inplace=True, drop = True)

# %%
df_covid_dates
# Out:
#                                                 Product     Category Price  \
# 0     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 1     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 2     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 3     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 4     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# ...                                                 ...          ...   ...
# 9965  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9966  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9967  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9968  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9969  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
#
#      Individual Review        Location       Date  \
# ...

# %%
df_covid_dates.isna().value_counts()
# Out:
# Product  Category  Price  Individual Review  Location  Date   Review  Helpful
# False    False     False  False              False     False  False   False      9966
#                                                               True    False         4
# dtype: int64

# %%
df_covid_dates["Review"].dropna(inplace= True)

# %%
df_covid_dates.isna().value_counts()
# Out:
# Product  Category  Price  Individual Review  Location  Date   Review  Helpful
# False    False     False  False              False     False  False   False      9966
#                                                               True    False         4
# dtype: int64

# %%
df_covid_dates = df_covid_dates.dropna()

# %%
df_covid_dates.isna().value_counts()
# Out:
# Product  Category  Price  Individual Review  Location  Date   Review  Helpful
# False    False     False  False              False     False  False   False      9966
# dtype: int64

# %%
df_covid_dates
# Out:
#                                                 Product     Category Price  \
# 0     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 1     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 2     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 3     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 4     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# ...                                                 ...          ...   ...
# 9965  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9966  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9967  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9968  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9969  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
#
#      Individual Review        Location       Date  \
# ...

# %%
df_covid_dates = df_covid_dates.reset_index(drop = True)

# %%
df_covid_dates
# Out:
#                                                 Product     Category Price  \
# 0     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 1     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 2     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 3     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# 4     TePe Oral Health Care, Interdental Brush, Mixe...  Health Care   nan
# ...                                                 ...          ...   ...
# 9961  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9962  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9963  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9964  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
# 9965  The 6-Minute Diary Pure | Gratitude Journal, M...  Health Care   nan
#
#      Individual Review        Location       Date  \
# ...

# %%
product_names = pd.DataFrame

# %%
product_names = df_covid_dates

# %%
product_names
# Out:
#                                                 Product Price
# 0     TePe Oral Health Care, Interdental Brush, Mixe...   nan
# 1     TePe Oral Health Care, Interdental Brush, Mixe...   nan
# 2     TePe Oral Health Care, Interdental Brush, Mixe...   nan
# 3     TePe Oral Health Care, Interdental Brush, Mixe...   nan
# 4     TePe Oral Health Care, Interdental Brush, Mixe...   nan
# ...                                                 ...   ...
# 9961  The 6-Minute Diary Pure | Gratitude Journal, M...   nan
# 9962  The 6-Minute Diary Pure | Gratitude Journal, M...   nan
# 9963  The 6-Minute Diary Pure | Gratitude Journal, M...   nan
# 9964  The 6-Minute Diary Pure | Gratitude Journal, M...   nan
# 9965  The 6-Minute Diary Pure | Gratitude Journal, M...   nan
#
# [9966 rows x 2 columns]

# %%
product_names = product_names.drop(columns=["Category","Individual Review","Location", "Date", "Review","Helpful"])

# %%
product_names.groupby(["Product"]).count()
# Out:
#                                                     Price
# Product
# 10 Pcs Baby Grooming Kit Baby Healthcare Kit Ne...      1
# 21st Century Health Care, Herbal Slimming Tea, ...     12
# Alexandra | Men's | Healthcare Tunic | Ideal fo...      2
# Alexandra | Women's | Contrast Trim Tunic (Zip)...      2
# Baby Grooming Kit, Infant Baby Healthcare Kit, ...    787
# Bodyclock Health Care Ltd - Self Adhesive Elect...     98
# Boxclever Press Luxury A5 Diary Cover. Textured...     39
# Brilliant Salmon Oil for Dogs, Cats, Puppy, Hor...      3
# Burde Diary 2022 Life Planner Pink | 20 Decembe...     30
# Dental Care Kit for Plaque Removal 4 Piece Tool...     72
# Eye Complex 7: Lutein, Meso-Zeaxanthin, Zeaxant...     90
# FLO Organic Non-Applicator Highly Absorbent Org...      3
# Foot Pads,Foot Patches, 100Pcs Feet Pads to Rem...     24
# Garden of Life Raw Probiotics Vaginal Care (She...    395
# GoGirl Planner and Organizer for Women – Compac...   1576
# ...

# %%
df_covid_dates.isna().value_counts()
# Out:
# Product  Category  Price  Individual Review  Location  Date   Review  Helpful
# False    False     False  False              False     False  False   False      9966
# dtype: int64

# %%
df_covid_dates.to_csv("../Cleaned_&_Sentimental_csv/health_care_for_sentimental.csv", index = False)
