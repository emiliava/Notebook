# %%
import pandas as pd
import tensorflow as tf
import re
import numpy as np
from nltk.corpus.reader import CategorizedCorpusReader
import nltk
from lime import lime_tabular

# %%
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# %%
df_cleaned = pd.read_excel("all_reviews_cleaned.xlsx", index_col=0)

# %%
data = df_cleaned.apply(lambda x: x.map(x.value_counts()))
data
# Out:
#         Hotel_Name   City  Country  Reviewer_Origin  Unit_Size  \
# 0           1830.0  62540    62540          26427.0       4284
# 1           1830.0  62540    62540           6005.0       4284
# 2           1830.0  62540    62540           6040.0       4284
# 3           1830.0  62540    62540           1917.0      10036
# 4           1830.0  62540    62540          77137.0       3607
# ...            ...    ...      ...              ...        ...
# 774056      1512.0  26079    26079           1868.0        152
# 774057      1512.0  26079    26079           3882.0       8450
# 774058      1512.0  26079    26079          31122.0       8450
# 774059      1512.0  26079    26079           8834.0       8450
# 774060      1512.0  26079    26079         163107.0       8450
#
#         Length_of_stay_nights  Group_Size  Review_Date  Review_Title  \
# 0                      137077      170817         6032           1.0
# 1                      179651      170817          825        1276.0
# 2                      179651      170817          973       59463.0
# 3                      137077      108428          973       51238.0
# 4                      251214      220530          973           1.0
# ...                       ...         ...          ...           ...
# 774056                 179651      108428         1408       16694.0
# 774057                 137077      108428          972       53660.0
# 774058                 137077      220530          972           1.0
# 774059                 137077      274286          972       51238.0
# 774060                 179651      108428         1065           1.0
#
#         Review_Score  Positive  Negative  num_of_people_helpful
# 0             236590       1.0       1.0                 668125
# 1              98180       1.0       1.0                 668125
# 2             103759       1.0       1.0                 668125
# 3              50901       1.0       1.0                 668125
# 4              50901      91.0       1.0                 668125
# ...              ...       ...       ...                    ...
# 774056         23528       1.0       1.0                 668125
# 774057         19578       1.0       1.0                 668125
# 774058         19578       1.0       1.0                 668125
# 774059         50901       1.0       1.0                 668125
# 774060         50901       1.0       1.0                 668125
#
# [774061 rows x 13 columns]

# %%
# If Reviewers Origin is less than 20 reviewers it is placed into a category called other
# this allows for the NN model to run

df_cleaned["Reviewer_Origin"] = df_cleaned["Reviewer_Origin"].where(data["Reviewer_Origin"] >=20, "other")

# %%
df_cleaned[df_cleaned["Reviewer_Origin"] == "other"]
# Out:
#                                       Hotel_Name        City      Country  \
# 482     Park Inn by Radisson Amsterdam City West   Amsterdam  Netherlands
# 723     Park Inn by Radisson Amsterdam City West   Amsterdam  Netherlands
# 1029    Park Inn by Radisson Amsterdam City West   Amsterdam  Netherlands
# 1125    Park Inn by Radisson Amsterdam City West   Amsterdam  Netherlands
# 1804    Park Inn by Radisson Amsterdam City West   Amsterdam  Netherlands
# ...                                          ...         ...          ...
# 772119                              Ibsens Hotel  Copenhagen      Denmark
# 772748                                 Alexandra  Copenhagen      Denmark
# 772817                                 Alexandra  Copenhagen      Denmark
# 773285                              Tivoli Hotel  Copenhagen      Denmark
# 773654                              Tivoli Hotel  Copenhagen      Denmark
#
#        Reviewer_Origin                      Unit_Size  Length_of_stay_nights  \
# 482              other                  Standard Room                      3
# 723              other                  Superior Room                      1
# 1029             other                  Superior Room                      3
# 1125             other                   Junior Suite                      2
# 1804             other   5 nights · \n\nNovember 2019                      5
# ...                ...                            ...                    ...
# 772119           other                    Medium Room                      2
# 772748           other           Standard Double Room                      3
# 772817           other           Standard Single Room                      2
# 773285           other           Standard Single Room                      5
# 773654           other  2 nights · \n\nSeptember 2019                      2
#
#            Group_Size Review_Date  \
# 482     Solo traveler  2019-12-05
# 723     Solo traveler  2019-08-13
# 1029    Solo traveler  2022-03-20
# 1125            Group  2021-10-24
# 1804    Solo traveler  2019-11-25
# ...               ...         ...
# 772119          Group  2019-10-16
# 772748  Solo traveler  2020-03-05
# 772817          Group  2021-11-04
# 773285  Solo traveler  2019-06-24
# 773654  Solo traveler  2019-09-22
#
#                                              Review_Title  Review_Score  \
# 482                                             Wonderful           9.2
# 723                                                  Good           7.1
# 1029                                             very bad           1.0
# 1125                                            Amsterdam           2.0
# 1804              Enjoyable, but I think a bit expensive.           6.0
# ...                                                   ...           ...
# 772119                                           Pleasant           6.2
# 772748                                          Very Good           8.0
# 772817  Overpriced for quality of room you get, but qu...           6.0
# 773285                                    Comfortable bed           7.5
# 773654                                          Very Poor           2.9
#
#                                                  Positive  \
# 482                                         all the rest.
# 723     the hotel and the location. friendly front des...
# 1029                                              nothing
# 1125    -once reached the hotel 4 p.m my rooms not rea...
# 1804    it was close to the train station and that mad...
# ...                                                   ...
# 772119  the room was really quiet. the checkin and our...
# 772748  the room under the roof was really cozy and wa...
# 772817  rooms are nicely decorated in the style of the...
# 773285                     set up and comfort of the room
# 773654  no bathrobe. not clean in bathroom. to small r...
#
#                                                  Negative  \
# 482     maybe with too many colours. not a lot of opti...
# 723     extremely poor service at the restaurant. sow ...
# 1029    very bad mattress\nshower water switch cold an...
# 1125    -once reached the hotel 4 p.m my rooms not rea...
# 1804    the room safe-box was broken and although i wa...
# ...                                                   ...
# 772119  toilet is integrated into the shower. not very...
# 772748  breakfast was rather modest, too few warm opti...
# 772817  a newspaper/folder received at check-in contai...
# 773285  room was not cleaned every day - i broke some ...
# 773654  no bathrobe. not clean in bathroom. to small r...
#
#         num_of_people_helpful
# 482                         0
# 723                         0
# 1029                        0
# 1125                        0
# 1804                        0
# ...                       ...
# 772119                      0
# 772748                      0
# 772817                      0
# 773285                      0
# 773654                      0
#
# [1319 rows x 13 columns]

# %%
df_cleaned.dtypes
# Out:
# Hotel_Name                       object
# City                             object
# Country                          object
# Reviewer_Origin                  object
# Unit_Size                        object
# Length_of_stay_nights             int64
# Group_Size                       object
# Review_Date              datetime64[ns]
# Review_Title                     object
# Review_Score                    float64
# Positive                         object
# Negative                         object
# num_of_people_helpful             int64
# dtype: object

# %%
df_cleaned.columns
# Out:
# Index(['Hotel_Name', 'City', 'Country', 'Reviewer_Origin', 'Unit_Size',
#        'Length_of_stay_nights', 'Group_Size', 'Review_Date', 'Review_Title',
#        'Review_Score', 'Positive', 'Negative', 'num_of_people_helpful'],
#       dtype='object')

# %%
# 'Positive', 'Negative' are removed

df_NN = df_cleaned[['City', 'Country', 'Reviewer_Origin',
       'Group_Size', 'Length_of_stay_nights', 'num_of_people_helpful',  
       'Review_Score']]
df_NN.dropna(inplace=True)
df_NN
# Out:
# <ipython-input-9-59d6089421ac>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NN.dropna(inplace=True)
#               City      Country           Reviewer_Origin     Group_Size  \
# 0        Amsterdam  Netherlands              South Africa  Solo traveler
# 1        Amsterdam  Netherlands                     Spain  Solo traveler
# 2        Amsterdam  Netherlands                    Poland  Solo traveler
# 3        Amsterdam  Netherlands                   Iceland          Group
# 4        Amsterdam  Netherlands  United States of America         Family
# ...            ...          ...                       ...            ...
# 774056  Copenhagen      Denmark                 Lithuania          Group
# 774057  Copenhagen      Denmark            Czech Republic          Group
# 774058  Copenhagen      Denmark                 Australia         Family
# 774059  Copenhagen      Denmark                  Thailand         Couple
# 774060  Copenhagen      Denmark            United Kingdom          Group
#
#         Length_of_stay_nights  num_of_people_helpful  Review_Score
# 0                           3                      0          10.0
# 1                           2                      0           8.0
# 2                           2                      0           9.0
# 3                           3                      0           7.0
# 4                           1                      0           7.0
# ...                       ...                    ...           ...
# 774056                      2                      0           8.8
# 774057                      3                      0           8.3
# 774058                      3                      0           8.3
# 774059                      3                      0           7.0
# 774060                      2                      0           7.0
#
# [774061 rows x 7 columns]

# %%
# example of ordinal encoding for a neural network
from tensorflow import keras
from tensorflow.keras import models
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder

# %%
df_NN[["num_of_people_helpful","Length_of_stay_nights"]] = df_NN[["num_of_people_helpful","Length_of_stay_nights"]].astype(int)
# Out:
# c:\Users\warne\Anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_NN.dtypes
# Out:
# City                      object
# Country                   object
# Reviewer_Origin           object
# Group_Size                object
# Length_of_stay_nights      int32
# num_of_people_helpful      int32
# Review_Score             float64
# dtype: object

# %%
df_NN.columns
# Out:
# Index(['City', 'Country', 'Reviewer_Origin', 'Group_Size',
#        'Length_of_stay_nights', 'num_of_people_helpful', 'Review_Score'],
#       dtype='object')

# %%
X = df_NN[['City', 'Country', 'Reviewer_Origin', 'Group_Size',
       'Length_of_stay_nights', 'num_of_people_helpful'
       ]]
Y = df_NN["Review_Score"]

# %%
X_train,X_test,y_train,y_test = train_test_split(df_NN.drop(columns=['Review_Score']),df_NN['Review_Score'],test_size=0.3)
print('Train/Test Sizes : ',X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# Train/Test Sizes :  (541842, 6) (232219, 6) (541842,) (232219,)

# %%
# Creation of neural network
neural_regressor = models.Sequential(
    [
        keras.layers.Dense(224, activation="relu", input_shape=(224,)),
        keras.layers.Dense(112, activation="relu"),
        keras.layers.Dense(52, activation="relu"),
        keras.layers.Dense(1)
    ]
)

neural_regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 224)               50400
#
#  dense_1 (Dense)             (None, 112)               25200
#
#  dense_2 (Dense)             (None, 52)                5876
#
#  dense_3 (Dense)             (None, 1)                 53
#
# =================================================================
# Total params: 81,529
# Trainable params: 81,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
#pip install scikeras

# %%
# Calling of scikeras API
from scikeras.wrappers import KerasRegressor

scikeras_regressor = KerasRegressor(model=neural_regressor,
                                    loss="mean_squared_error",
                                    optimizer="adam",
                                    verbose=1,
                                    epochs=50,
                                    batch_size= 40,
                                    warm_start= True
                                  )

# %%
# Creation of pipeline process, Seperation of numeric, categorical and ordinal variables

numeric_features = ['Length_of_stay_nights', 'num_of_people_helpful']
numeric_transformer = MinMaxScaler()

categorical_features = ['City', 'Country', 'Reviewer_Origin']
categorical_transformer = OneHotEncoder()

ordinal_features = ['Group_Size']
ordinal_transformer = OrdinalEncoder()


#text_features = ["Positive","Negative"]
#tfid_transformer = TfidfVectorizer(stop_words = 'english', max_features= 5000)


preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
        ("ord", ordinal_transformer, ordinal_features),
        #("text", tfid_transformer, text_features)        
    ], 
    sparse_threshold=0
)

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("scale", StandardScaler()),
        ('Model', scikeras_regressor)
        ]
)

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 2060

# %%
## Declare Hyperparameters Range
# Tested batch_size: 10, 20, 40, 60, 80, 100
# Tested Optimizers: Adam, SGD
# Tested epochs: 10, 20, 50, 100
# 
# Best Params : {'Model__batch_size': 20, 'Model__epochs': 20, 'Model__optimizer': 'adam
# Test  R^2 : 0.017656446414898386

# Best Params : {'Model__batch_size': 40, 'Model__epochs': 50, 'Model__optimizer': 'adam'}
# Test  R^2 : 0.018041664269548896

params = {
    "Model__batch_size": [10, 20, 40, 60, 80, 100],
    "Model__optimizer": ["adam"],
    "Model__epochs": [10, 20, 50, 100]
}

# %%
# Used to find the optimal parameters
# Already run, best one is {'Model__batch_size': 40, 'Model__epochs': 50, 'Model__optimizer': 'adam'}
#grid = GridSearchCV(pipeline, param_grid = params, scoring="r2", n_jobs = 3, verbose=10)

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('num', MinMaxScaler(),
#                                                   ['Length_of_stay_nights',
#                                                    'num_of_people_helpful']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['City', 'Country',
#                                                    'Reviewer_Origin']),
#                                                  ('ord', OrdinalEncoder(),
#                                                   ['Group_Size'])])),
#                 ('scale', StandardScaler()),
#                 ('Model',
#                  KerasRegressor(batch_size=40, epochs=50, loss='mean_squared_error', model=<keras.engine.sequential.Sequential object at 0x0000026962CE8880>, optimizer='adam', warm_start=True))])

# %%
# Used to run just the best model, not all of gridsearch
pipeline.fit(X_train, y_train)
# Out:
# Epoch 1/50
# 13547/13547 [==============================] - 39s 3ms/step - loss: 4.2858
# Epoch 2/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.1074
# Epoch 3/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.0640
# Epoch 4/50
# 13547/13547 [==============================] - 43s 3ms/step - loss: 4.0377
# Epoch 5/50
# 13547/13547 [==============================] - 41s 3ms/step - loss: 4.0318
# Epoch 6/50
# 13547/13547 [==============================] - 38s 3ms/step - loss: 4.0304
# Epoch 7/50
# 13547/13547 [==============================] - 36s 3ms/step - loss: 4.0283
# Epoch 8/50
# 13547/13547 [==============================] - 36s 3ms/step - loss: 4.0277
# Epoch 9/50
# 13547/13547 [==============================] - 36s 3ms/step - loss: 4.0258
# Epoch 10/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.0256
# Epoch 11/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.0253
# Epoch 12/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.0236
# Epoch 13/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.0235
# Epoch 14/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0236
# Epoch 15/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0218
# Epoch 16/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0208
# Epoch 17/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0217
# Epoch 18/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0202
# Epoch 19/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0192
# Epoch 20/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0203
# Epoch 21/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0199
# Epoch 22/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0184
# Epoch 23/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0193
# Epoch 24/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0223
# Epoch 25/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0188
# Epoch 26/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0181
# Epoch 27/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0169
# Epoch 28/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0165
# Epoch 29/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0164
# Epoch 30/50
# 13547/13547 [==============================] - 35s 3ms/step - loss: 4.0145
# Epoch 31/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0151
# Epoch 32/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0163
# Epoch 33/50
# 13547/13547 [==============================] - 36s 3ms/step - loss: 4.0156
# Epoch 34/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0150
# Epoch 35/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0153
# Epoch 36/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0142
# Epoch 37/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0137
# Epoch 38/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0151
# Epoch 39/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0129
# Epoch 40/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0126
# Epoch 41/50
# 13547/13547 [==============================] - 40s 3ms/step - loss: 4.0137
# Epoch 42/50
# 13547/13547 [==============================] - 34s 2ms/step - loss: 4.0123
# Epoch 43/50
# 13547/13547 [==============================] - 33s 2ms/step - loss: 4.0099
# Epoch 44/50
# 13547/13547 [==============================] - 31s 2ms/step - loss: 4.0099
# Epoch 45/50
# 13547/13547 [==============================] - 34s 3ms/step - loss: 4.0105
# Epoch 46/50
# 13547/13547 [==============================] - 38s 3ms/step - loss: 4.0087
# Epoch 47/50
# 13547/13547 [==============================] - 38s 3ms/step - loss: 4.0075
# Epoch 48/50
# 13547/13547 [==============================] - 37s 3ms/step - loss: 4.0079
# Epoch 49/50
# 13547/13547 [==============================] - 34s 2ms/step - loss: 4.0060
# Epoch 50/50
# 13547/13547 [==============================] - 36s 3ms/step - loss: 4.0077
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('num', MinMaxScaler(),
#                                                   ['Length_of_stay_nights',
#                                                    'num_of_people_helpful']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['City', 'Country',
#                                                    'Reviewer_Origin']),
#                                                  ('ord', OrdinalEncoder(),
#                                                   ['Group_Size'])])),
#                 ('scale', StandardScaler()),
#                 ('Model',
#                  KerasRegressor(batch_size=40, epochs=50, loss='mean_squared_error', model=<keras.engine.sequential.Sequential object at 0x0000026962CE8880>, optimizer='adam', warm_start=True))])

# %%
from sklearn.metrics import mean_squared_error

print("Train MSE : {}".format(mean_squared_error(y_train, pipeline.predict(X_train))))
print("Test  MSE : {}".format(mean_squared_error(y_test, pipeline.predict(X_test))))
# Out:
# 13547/13547 [==============================] - 16s 1ms/step
# Train MSE : 3.9989620076854955
# 5806/5806 [==============================] - 7s 1ms/step
# Test  MSE : 4.059540653602671

# %%
print("\nTrain R^2 : {}".format(pipeline.score(X_train, y_train)))
print("Test  R^2 : {}".format(pipeline.score(X_test, y_test)))
# Out:
# 13547/13547 [==============================] - 17s 1ms/step
#
# Train R^2 : 0.02672692975315405
# 5806/5806 [==============================] - 7s 1ms/step
# Test  R^2 : 0.016020503102327388

# %%
#print("Best Score  : {}".format(grid.best_score_))
#print("Best Params : {}".format(grid.best_params_))
# Out:
# Best Score  : 0.01718233798467461
# Best Params : {'Model__batch_size': 40, 'Model__epochs': 50, 'Model__optimizer': 'adam'}

# %%
# With out standard scaler
#from sklearn.metrics import mean_squared_error

#print("Train MSE : {}".format(mean_squared_error(y_train, grid.predict(X_train))))
#print("Test  MSE : {}".format(mean_squared_error(y_test, grid.predict(X_test))))
# Out:
# Train MSE : 4.00225861110458
# Test  MSE : 4.052882423668592

# %%
#print("\nTrain R^2 : {}".format(grid.score(X_train, y_train)))
#print("Test  R^2 : {}".format(grid.score(X_test, y_test)))
# Out:
# Train R^2 : 0.025751127790847428
# Test  R^2 : 0.018041664269548896

# %%
#scikeras_regressor.model.save("keras_regressor_30hrs")

# %%
#grid.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(sparse_threshold=0,
#                                                           transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['Length_of_stay_nights',
#                                                                           'num_of_people_helpful']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(),
#                                                                          ['City',
#                                                                           'Country',
#                                                                           'Reviewer_Origin']),
#                                                                         ('ord',
#                                                                          OrdinalEncoder(),
#                                                                          ['Group_Size'])])),
#                                        ('scale', StandardScaler()),
#                                        ('Model',
#                                         KerasRegressor(batch_size=20, epochs=20, loss='mean_squared_error', model=<keras.engine.sequential.Sequential object at 0x00000193C39C1520>, optimizer='adam', verbose=0, warm_start=True))]),
#              n_jobs=2,
#              param_grid={'Model__batch_size': [20, 40, 60, 80, 100],
#                          'Model__epochs': [50, 100],
#                          'Model__optimizer': ['adam', 'sgd']},
#              scoring='r2', verbose=3)>

# %%
allscores= pd.read_csv("gridsearchCV_results.csv", index_col=0)
allscores
# Out:
#                std_fit_time  mean_score_time  std_score_time  \
# mean_fit_time
# 0.0             3027.447814        63.049185       15.012960
# 1.0             2738.616238        18.252430        9.333782
# 2.0             7561.165366      1988.995056       11.529417
# 3.0             5324.621817        35.191130        9.255937
# 4.0             1475.069366         7.383413        5.616255
# 5.0             1360.888494         6.171748        6.124391
# 6.0             8255.756581      6398.756802        5.315254
# 7.0             2800.147782         7.992454        5.703060
# 8.0             1032.205235        23.787302        4.346321
# 9.0              925.460727        12.946176        3.979057
# 10.0            2007.422872        14.579569        4.028781
# 11.0            1835.211793        17.140466        4.592158
# 12.0             782.599334        12.560965        6.273060
# 13.0             730.311471        43.777660        3.918074
# 14.0            1522.076011        25.371240        3.397732
# 15.0            1426.652842        35.767049        3.872547
# 16.0             924.359446       146.326008        3.632515
# 17.0             630.209116        29.776682        3.836520
# 18.0            1907.167038       260.893983        4.383641
# 19.0            1159.486869        17.851542        2.571964
# NaN                     NaN              NaN             NaN
# NaN                     NaN              NaN    56710.170500
# NaN                     NaN              NaN      945.169508
#
#                param_Model__batch_size  param_Model__epochs  \
# mean_fit_time
# 0.0                           7.648083                 20.0
# 1.0                           0.123211                 20.0
# 2.0                           1.729778                 20.0
# 3.0                           0.143706                 20.0
# 4.0                           0.644619                 40.0
# 5.0                           0.538755                 40.0
# 6.0                           0.170176                 40.0
# 7.0                           0.733097                 40.0
# 8.0                           0.478480                 60.0
# 9.0                           0.273915                 60.0
# 10.0                          0.203730                 60.0
# 11.0                          0.532134                 60.0
# 12.0                          4.850444                 80.0
# 13.0                          1.113053                 80.0
# 14.0                          0.231989                 80.0
# 15.0                          0.935663                 80.0
# 16.0                          0.992237                100.0
# 17.0                          0.888596                100.0
# 18.0                          1.129953                100.0
# 19.0                          0.430616                100.0
# NaN                                NaN                  NaN
# NaN                                NaN                  NaN
# NaN                                NaN                  NaN
#
#                param_Model__optimizer params  \
# mean_fit_time
# 0.0                              50.0   adam
# 1.0                              50.0    sgd
# 2.0                             100.0   adam
# 3.0                             100.0    sgd
# 4.0                              50.0   adam
# 5.0                              50.0    sgd
# 6.0                             100.0   adam
# 7.0                             100.0    sgd
# 8.0                              50.0   adam
# 9.0                              50.0    sgd
# 10.0                            100.0   adam
# 11.0                            100.0    sgd
# 12.0                             50.0   adam
# 13.0                             50.0    sgd
# 14.0                            100.0   adam
# 15.0                            100.0    sgd
# 16.0                             50.0   adam
# 17.0                             50.0    sgd
# 18.0                            100.0   adam
# 19.0                            100.0    sgd
# NaN                               NaN    NaN
# NaN                               NaN    NaN
# NaN                               NaN    NaN
#
#                                                split0_test_score  \
# mean_fit_time
# 0.0            {'Model__batch_size': 20, 'Model__epochs': 50,...
# 1.0            {'Model__batch_size': 20, 'Model__epochs': 50,...
# 2.0            {'Model__batch_size': 20, 'Model__epochs': 100...
# 3.0            {'Model__batch_size': 20, 'Model__epochs': 100...
# 4.0            {'Model__batch_size': 40, 'Model__epochs': 50,...
# 5.0            {'Model__batch_size': 40, 'Model__epochs': 50,...
# 6.0            {'Model__batch_size': 40, 'Model__epochs': 100...
# 7.0            {'Model__batch_size': 40, 'Model__epochs': 100...
# 8.0            {'Model__batch_size': 60, 'Model__epochs': 50,...
# 9.0            {'Model__batch_size': 60, 'Model__epochs': 50,...
# 10.0           {'Model__batch_size': 60, 'Model__epochs': 100...
# 11.0           {'Model__batch_size': 60, 'Model__epochs': 100...
# 12.0           {'Model__batch_size': 80, 'Model__epochs': 50,...
# 13.0           {'Model__batch_size': 80, 'Model__epochs': 50,...
# 14.0           {'Model__batch_size': 80, 'Model__epochs': 100...
# 15.0           {'Model__batch_size': 80, 'Model__epochs': 100...
# 16.0           {'Model__batch_size': 100, 'Model__epochs': 50...
# 17.0           {'Model__batch_size': 100, 'Model__epochs': 50...
# 18.0           {'Model__batch_size': 100, 'Model__epochs': 10...
# 19.0           {'Model__batch_size': 100, 'Model__epochs': 10...
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                split1_test_score  split2_test_score  split3_test_score  \
# mean_fit_time
# 0.0                     0.015833           0.016437           0.019686
# 1.0                          NaN                NaN                NaN
# 2.0                     0.017380           0.010837           0.016469
# 3.0                          NaN                NaN          -0.000057
# 4.0                     0.017267           0.014205           0.019329
# 5.0                          NaN           0.012313                NaN
# 6.0                     0.016909           0.013964           0.019595
# 7.0                     0.004048                NaN                NaN
# 8.0                     0.017426           0.010994           0.017545
# 9.0                     0.010867           0.013756                NaN
# 10.0                    0.005852           0.012288           0.018647
# 11.0                         NaN           0.005219           0.007913
# 12.0                    0.011080           0.015971           0.018437
# 13.0                    0.014660           0.014117           0.016633
# 14.0                    0.016075           0.012839           0.016179
# 15.0                         NaN                NaN           0.006724
# 16.0                    0.017338           0.014216           0.019309
# 17.0                    0.014320           0.010332           0.017376
# 18.0                    0.014115           0.012791           0.018112
# 19.0                    0.004623          -0.000136           0.006561
# NaN                          NaN                NaN                NaN
# NaN                          NaN                NaN                NaN
# NaN                          NaN                NaN                NaN
#
#                split4_test_score  mean_test_score  std_test_score  \
# mean_fit_time
# 0.0                     0.017207         0.014979        0.016828
# 1.0                          NaN              NaN             NaN
# 2.0                     0.016564         0.015994        0.015449
# 3.0                          NaN              NaN             NaN
# 4.0                     0.018286         0.016825        0.017182
# 5.0                     0.012639         0.014305             NaN
# 6.0                     0.011924         0.010014        0.014481
# 7.0                     0.002703              NaN             NaN
# 8.0                     0.017307         0.016675        0.015989
# 9.0                     0.013898         0.013978             NaN
# 10.0                    0.012580         0.012855        0.012444
# 11.0                         NaN              NaN             NaN
# 12.0                    0.013336         0.017619        0.015289
# 13.0                         NaN         0.013430             NaN
# 14.0                    0.015234         0.012084        0.014482
# 15.0                         NaN         0.001619             NaN
# 16.0                    0.018879         0.011840        0.016317
# 17.0                         NaN         0.013559             NaN
# 18.0                    0.013667         0.013749        0.014487
# 19.0                         NaN         0.004842             NaN
# NaN                          NaN              NaN             NaN
# NaN                          NaN              NaN             NaN
# NaN                          NaN              NaN             NaN
#
#                rank_test_score  Unnamed: 16
# mean_fit_time
# 0.0                   0.001605          2.0
# 1.0                        NaN         18.0
# 2.0                   0.002349          5.0
# 3.0                        NaN         17.0
# 4.0                   0.001722          1.0
# 5.0                        NaN         16.0
# 6.0                   0.003430          9.0
# 7.0                        NaN         15.0
# 8.0                   0.002516          4.0
# 9.0                        NaN         14.0
# 10.0                  0.004053         10.0
# 11.0                       NaN         19.0
# 12.0                  0.002732          6.0
# 13.0                       NaN         13.0
# 14.0                  0.001699          8.0
# 15.0                       NaN         12.0
# 16.0                  0.002864          3.0
# 17.0                       NaN         11.0
# 18.0                  0.001864          7.0
# 19.0                       NaN         20.0
# NaN                        NaN          NaN
# NaN                        NaN          NaN
# NaN                        NaN          NaN
